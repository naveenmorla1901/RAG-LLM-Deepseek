# %%
import pandas as pd
import numpy as np
from pathlib import Path
from document_processor import DocumentProcessor
from langchain_community.document_loaders import PyPDFLoader
import logging
from tqdm import tqdm

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Initialize processor
processor = DocumentProcessor()

# Project paths
PROJECT_ROOT = Path().absolute()
DATA_DIR = PROJECT_ROOT / 'data' / 'raw'

def inspect_document_store():
    """Inspect current state of processed documents"""
    print("\nCurrently processed files:")
    for file_path, file_hash in processor.processed_files.items():
        print(f"- {file_path}")
    
    print("\nChromaDB collection info:")
    total_docs = processor.collection.count()
    print(f"Total documents: {total_docs}")
    
    # Get collection stats
    results = processor.collection.get()
    if results['metadatas']:
        doc_types = {}
        sources = {}
        for metadata in results['metadatas']:
            doc_type = metadata.get('type', 'unknown')
            source = metadata.get('source', 'unknown')
            doc_types[doc_type] = doc_types.get(doc_type, 0) + 1
            sources[Path(source).name] = sources.get(Path(source).name, 0) + 1
        
        print("\nDocument types distribution:")
        for doc_type, count in doc_types.items():
            print(f"- {doc_type}: {count} chunks")
            
        print("\nSource files distribution:")
        for source, count in sources.items():
            print(f"- {source}: {count} chunks")

# Inspect current state
inspect_document_store()
# Out:
# INFO:config:✓ Environment variables validated
# INFO:config:✓ ChromaDB client initialized at chroma_db
# INFO:config:✓ Collection 'loan_documents' ready
# INFO:document_processor:✓ Document processor initialized
# Currently processed files:
# - data\raw\loan_applications\Personal-Loan-Application-with-Disclosures-Fill-Form.pdf
# - data\raw\loan_applications\URLA_2019_Borrower_v28.pdf
# - data\raw\policy_documents\mill-citiescommunity-investments-loan-policies.pdf
# - data\raw\policy_documents\section3-2.pdf
# - data\raw\training_data\accepted_2007_to_2018Q4.csv
# - data\raw\training_data\rejected_2007_to_2018Q4.csv
#
# ChromaDB collection info:
# Total documents: 8101
#
# Document types distribution:
# - pdf: 1939 chunks
# - csv: 6162 chunks
#
# Source files distribution:
# - Personal-Loan-Application-with-Disclosures-Fill-Form.pdf: 26 chunks
# - URLA_2019_Borrower_v28.pdf: 64 chunks
# - mill-citiescommunity-investments-loan-policies.pdf: 163 chunks
# - section3-2.pdf: 1686 chunks
# - accepted_2007_to_2018Q4.csv: 5152 chunks
# - rejected_2007_to_2018Q4.csv: 1010 chunks

# %%
from pytesseract import image_to_string
from pdf2image import convert_from_path

def ocr_pdf(file_path: Path):
    """Perform OCR on PDF pages"""
    try:
        print("\nAttempting OCR...")
        images = convert_from_path(file_path)
        ocr_text = "\n".join(image_to_string(img) for img in images)
        return ocr_text
    except Exception as e:
        logger.error(f"OCR failed: {str(e)}")
        return None

# %%
def analyze_pdf_quality(file_path: Path):
    """Analyze PDF document quality and content structure with OCR fallback"""
    try:
        # Try standard text extraction first
        from pdfminer.high_level import extract_text
        from pdfplumber import open as pdfplumber_open
        from PyPDF2 import PdfReader
        
        print(f"\nAnalyzing {file_path.name}:")
        
        # Method 1: PyPDFLoader
        loader = PyPDFLoader(str(file_path))
        pages = loader.load()
        print(f"PyPDFLoader pages: {len(pages)}")
        
        # Method 2: pdfminer
        pdfminer_text = extract_text(file_path)
        print(f"pdfminer text length: {len(pdfminer_text)}")
        
        # Method 3: pdfplumber
        with pdfplumber_open(file_path) as pdf:
            pdfplumber_text = "\n".join(page.extract_text() for page in pdf.pages)
            print(f"pdfplumber text length: {len(pdfplumber_text)}")
        
        # Method 4: PyPDF2
        reader = PdfReader(file_path)
        pypdf2_text = "\n".join(page.extract_text() for page in reader.pages)
        print(f"PyPDF2 text length: {len(pypdf2_text)}")
        
        # Choose the method with most content
        best_text = max([pdfminer_text, pdfplumber_text, pypdf2_text], key=len)
        
        if not best_text.strip():
            print("\nWARNING: No text could be extracted from this PDF")
            print("Attempting OCR...")
            
            # OCR fallback
            ocr_text = ocr_pdf(file_path)
            if ocr_text:
                print(f"OCR extracted {len(ocr_text)} characters")
                best_text = ocr_text
            else:
                print("OCR failed to extract text")
                return None
            
        # Content analysis
        content_stats = {
            'total_chars': len(best_text),
            'form_fields': 0,
            'pages': []
        }
        
        # Split text by pages (approximate)
        page_texts = best_text.split('\f') if '\f' in best_text else [best_text]
        
        for i, page_text in enumerate(page_texts):
            # Check for potential form fields
            form_fields = [line.strip() for line in page_text.split('\n') 
                         if ':' in line and len(line.split(':')[0]) < 50]
            
            # Page statistics
            page_stats = {
                'page_num': i + 1,
                'char_count': len(page_text),
                'form_fields': form_fields,
                'text_preview': page_text[:200]
            }
            content_stats['pages'].append(page_stats)
            content_stats['form_fields'] += len(form_fields)
        
        print("\nContent Statistics:")
        print(f"Total characters: {content_stats['total_chars']}")
        print(f"Form fields detected: {content_stats['form_fields']}")
        
        print("\nPage Analysis:")
        for page in content_stats['pages']:
            print(f"\nPage {page['page_num']}:")
            print(f"Characters: {page['char_count']}")
            if page['form_fields']:
                print("Form fields found:")
                for field in page['form_fields'][:5]:
                    print(f"  - {field}")
                if len(page['form_fields']) > 5:
                    print(f"  ... and {len(page['form_fields'])-5} more fields")
            
        return content_stats
        
    except Exception as e:
        logger.error(f"Error analyzing PDF {file_path}: {str(e)}")
        return None

# %%
def analyze_csv_quality(file_path: Path):
    """Analyze CSV data quality and structure"""
    try:
        # Read CSV with better error handling
        df = pd.read_csv(file_path, low_memory=False)
        
        print(f"\nAnalyzing {file_path.name}:")
        print(f"Shape: {df.shape}")
        
        # Data quality analysis
        quality_stats = {
            'missing_values': {},
            'unique_values': {},
            'numeric_stats': {},
            'categorical_stats': {},
            'potential_issues': []
        }
        
        # Analyze each column
        for column in df.columns:
            # Missing values
            missing = df[column].isnull().sum()
            missing_pct = (missing / len(df)) * 100
            quality_stats['missing_values'][column] = missing_pct
            
            if missing_pct > 20:
                quality_stats['potential_issues'].append(
                    f"High missing values in {column}: {missing_pct:.1f}%"
                )
            
            # Unique values analysis
            unique_count = df[column].nunique()
            unique_pct = (unique_count / len(df)) * 100
            quality_stats['unique_values'][column] = unique_count
            
            # Identify potential ID columns
            if unique_pct > 90:
                quality_stats['potential_issues'].append(
                    f"{column} might be an ID column ({unique_pct:.1f}% unique values)"
                )
            
            # Analyze by data type
            if pd.api.types.is_numeric_dtype(df[column]):
                try:
                    stats = {
                        'mean': df[column].mean(),
                        'std': df[column].std(),
                        'min': df[column].min(),
                        'max': df[column].max(),
                        'zeros_pct': (df[column] == 0).mean() * 100
                    }
                    quality_stats['numeric_stats'][column] = stats
                    
                    # Check for outliers using IQR
                    Q1 = df[column].quantile(0.25)
                    Q3 = df[column].quantile(0.75)
                    IQR = Q3 - Q1
                    outliers = df[column][(df[column] < (Q1 - 1.5 * IQR)) | 
                                        (df[column] > (Q3 + 1.5 * IQR))]
                    if len(outliers) > 0:
                        pct_outliers = (len(outliers) / len(df)) * 100
                        if pct_outliers > 5:
                            quality_stats['potential_issues'].append(
                                f"High outliers in {column}: {pct_outliers:.1f}% of values"
                            )
                except Exception as e:
                    logger.warning(f"Error analyzing numeric column {column}: {str(e)}")
            else:
                # Categorical analysis
                value_counts = df[column].value_counts()
                quality_stats['categorical_stats'][column] = {
                    'top_values': value_counts.head().to_dict(),
                    'unique_count': unique_count
                }
        
        # Print analysis results
        print("\nData Quality Summary:")
        
        print("\nMissing Values (%):")
        for col, pct in quality_stats['missing_values'].items():
            if pct > 0:
                print(f"- {col}: {pct:.1f}%")
        
        print("\nNumeric Columns Statistics:")
        for col, stats in quality_stats['numeric_stats'].items():
            print(f"\n{col}:")
            for stat_name, value in stats.items():
                print(f"  {stat_name}: {value:.2f}")
        
        print("\nCategorical Columns:")
        for col, stats in quality_stats['categorical_stats'].items():
            print(f"\n{col}:")
            print(f"  Unique values: {stats['unique_count']}")
            if len(stats['top_values']) < 10:
                print("  Value distribution:")
                for val, count in stats['top_values'].items():
                    print(f"    - {val}: {count}")
        
        if quality_stats['potential_issues']:
            print("\nPotential Data Quality Issues:")
            for issue in quality_stats['potential_issues']:
                print(f"- {issue}")
                
        return quality_stats
        
    except Exception as e:
        logger.error(f"Error analyzing CSV {file_path}: {str(e)}")
        return None

# %%
# Analyze documents
print("Analyzing Documents...")

# Process PDFs
print("\nAnalyzing PDF Documents:")
for pdf_file in Path(DATA_DIR).rglob('*.pdf'):
    pdf_stats = analyze_pdf_quality(pdf_file)

# Process CSVs
print("\nAnalyzing CSV Documents:")
for csv_file in Path(DATA_DIR).rglob('*.csv'):
    csv_stats = analyze_csv_quality(csv_file)

# Verify processed data
print("\nVerifying processed data...")
inspect_document_store()

# Save analysis results
print("\nProcessing complete. Check the analysis output above for data quality issues.")
# Out:
# Analyzing Documents...
#
# Analyzing PDF Documents:
#
# Analyzing Personal-Loan-Application-with-Disclosures-Fill-Form.pdf:
# PyPDFLoader pages: 4
# pdfminer text length: 9932
# pdfplumber text length: 9191
# PyPDF2 text length: 9396
#
# Content Statistics:
# Total characters: 9932
# Form fields detected: 20
#
# Page Analysis:
#
# Page 1:
# Characters: 6480
# Form fields found:
#   - IMPORTANT: Read these Directions before completing this Application. Check the Appropriate Box.
#   - ADDRESS:
#   - ADDRESS:
#   - ADDRESS:
#   - IS:
#   ... and 9 more fields
#
# Page 2:
# Characters: 630
# Form fields found:
#   - What this means for you:
#
# Page 3:
# Characters: 1789
# Form fields found:
#   - type:
#   - Dated:
#   - Dated:
#   - By:
#
# Page 4:
# Characters: 1029
# Form fields found:
#   - with the above Financial Institution:
#
# Page 5:
# Characters: 0
#
# Analyzing URLA_2019_Borrower_v28.pdf:
# PyPDFLoader pages: 9
# pdfminer text length: 24397
# pdfplumber text length: 23038
# PyPDF2 text length: 23452
#
# Content Statistics:
# Total characters: 24397
# Form fields detected: 55
#
# Page Analysis:
#
# Page 1:
# Characters: 3066
# Form fields found:
#   - To be completed by the Lender:
#   - Section 1: Borrower Information. This section asks about your personal information and your income from
#   - Check if this statement applies:
#
# Page 2:
# Characters: 2191
# Form fields found:
#   - Check if this statement applies:
#   - NOTE: Reveal alimony, child support, separate maintenance, or other income ONLY IF you want it considered in determining your qualification
#   - Borrower Name:
#
# Page 3:
# Characters: 2375
# Form fields found:
#   - Section 2: Financial Information — Assets and Liabilities. This section asks about things you own that
#   - Borrower Name:
#
# Page 4:
# Characters: 2626
# Form fields found:
#   - Section 3: Financial Information — Real Estate. This section asks you to list all properties you currently own
#   - Status: Sold,
#   - Intended Occupancy:
#   - For LENDER  to calculate:
#   - Type: FHA, VA,
#   ... and 9 more fields
#
# Page 5:
# Characters: 1983
# Form fields found:
#   - Section 4: Loan and Property Information. This section asks about the loan’s purpose and the property you
#   - For LENDER to calculate: Expected Net Monthly Rental Income
#   - Asset Type: Cash Gift, Gift of Equity, Grant
#   - Borrower Name:
#
# Page 6:
# Characters: 2800
# Form fields found:
#   - Section 5: Declarations. This section asks you specific questions about the property, your funding, and your past
#   - If YES, complete (1) and (2) below:
#   - (1) What type of property did you own: primary residence (PR), FHA secondary residence (SR), second home (SH),
#   - (2) How did you hold title to the property: by yourself (S), jointly with your spouse (SP), or jointly with another person (O)?
#   - If this is a Purchase Transaction: Do you have a family relationship or business affiliation with the seller of the property?
#   ... and 2 more fields
#
# Page 7:
# Characters: 5405
# Form fields found:
#   - Section 6: Acknowledgments and Agreements. This section tells you about your legal obligations when
#   - Definitions:
#   - • For purchase transactions:  The terms and conditions of any real
#   - result in the imposition of:
#   - an interest in my loan or its servicing:
#   ... and 1 more fields
#
# Page 8:
# Characters: 3460
# Form fields found:
#   - Section 7: Military Service. This section asks questions about your (or your deceased spouse's) military service.
#   - If YES, check all that apply:
#   - Section 8: Demographic Information. This section asks about your ethnicity, sex, and race.
#   - Ethnicity: Check one or more
#   - – Print origin:
#   ... and 9 more fields
#
# Page 9:
# Characters: 482
# Form fields found:
#   - Section 9: Loan Originator Information. To be completed by your Loan Originator.
#   - Borrower Name:
#
# Page 10:
# Characters: 0
#
# Analyzing mill-citiescommunity-investments-loan-policies.pdf:
# PyPDFLoader pages: 22
# pdfminer text length: 53745
# pdfplumber text length: 51352
# PyPDF2 text length: 53599
#
# Content Statistics:
# Total characters: 53745
# Form fields detected: 22
#
# Page Analysis:
#
# Page 1:
# Characters: 219
#
# Page 2:
# Characters: 1926
# Form fields found:
#   - Table of Contents:                                                                                                                      Page#
#
# Page 3:
# Characters: 2087
#
# Page 4:
# Characters: 2932
# Form fields found:
#   - 1. Objective:
#   - 2. General Policy:
#   - conflict of interest and will not be accepted:
#
# Page 5:
# Characters: 2993
# Form fields found:
#   - need a full board approval prior to commitment:
#   - MCCI will offer the following loan products:
#
# Page 6:
# Characters: 2852
# Form fields found:
#   - G.   Pricing of loans:
#   - fixed as follows:
#
# Page 7:
# Characters: 2700
# Form fields found:
#   - consummation of the loan):
#   - be able to provide the following information:
#
# Page 8:
# Characters: 3495
# Form fields found:
#   - Credit history: A credit report will be obtained for most loans.  After obtaining an initial
#
# Page 9:
# Characters: 2985
# Form fields found:
#   - Alternative credit history: An alternative means may be used to develop a credit history,
#   - be able to provide the following information:
#
# Page 10:
# Characters: 3280
# Form fields found:
#   - Credit history: A credit report will be obtained for most loans.
#   - Alternative credit history: An alternative means may be used to develop a credit history,
#
# Page 11:
# Characters: 3202
#
# Page 12:
# Characters: 3618
#
# Page 13:
# Characters: 3256
#
# Page 14:
# Characters: 2503
# Form fields found:
#   - A Seven point risk scale will be utilized:
#
# Page 15:
# Characters: 2496
# Form fields found:
#   - the following:
#
# Page 16:
# Characters: 2363
# Form fields found:
#   - committee. Recommended action may include:
#
# Page 17:
# Characters: 2515
#
# Page 18:
# Characters: 2733
#
# Page 19:
# Characters: 2519
# Form fields found:
#   - that can be used to assist:
#
# Page 20:
# Characters: 2795
# Form fields found:
#   - Right to rescind: Borrowers will be given notice prior to the consummation of their loan
#
# Page 21:
# Characters: 154
# Form fields found:
#   - List of Approved Appraisers:
#
# Page 22:
# Characters: 100
# Form fields found:
#   - List of Approved Closing Attorneys:
#
# Page 23:
# Characters: 0
#
# Analyzing section3-2.pdf:
# PyPDFLoader pages: 93
# pdfminer text length: 543032
# pdfplumber text length: 501465
# PyPDF2 text length: 516138
#
# Content Statistics:
# Total characters: 543032
# Form fields detected: 105
#
# Page Analysis:
#
# Page 1:
# Characters: 8089
#
# Page 2:
# Characters: 7231
#
# Page 3:
# Characters: 5534
# Form fields found:
#   - following:
#
# Page 4:
# Characters: 5446
# Form fields found:
#   - Note: The allowance for credit losses on loans and leases
#   - designed to address the following objectives:
#   - includes the following:
#
# Page 5:
# Characters: 4914
# Form fields found:
#   - following items:
#   - factors, including:
#
# Page 6:
# Characters: 6249
#
# Page 7:
# Characters: 5451
# Form fields found:
#   - should consist of the following items:
#   - provide for them in the ALLL:
#
# Page 8:
# Characters: 5570
# Form fields found:
#   - historical loss experience such as:
#   - when management has:
#
# Page 9:
# Characters: 5120
# Form fields found:
#   - methodology should:
#
# Page 10:
# Characters: 6017
# Form fields found:
#   - the  borrower's  viewpoint  are:    it  is  an  efficient  way  to
#   - Advantages from the institution's viewpoint are: it generates
#
# Page 11:
# Characters: 5359
# Form fields found:
#   - combination of the following:
#   - maintaining the following:
#
# Page 12:
# Characters: 5232
# Form fields found:
#   - leveraged lending generally address the following:
#   - for:
#
# Page 13:
# Characters: 5634
# Form fields found:
#   - transactions typically ensures that:
#
# Page 14:
# Characters: 6153
#
# Page 15:
# Characters: 5469
# Form fields found:
#   - include the following:
#   - typically includes the following:
#
# Page 16:
# Characters: 5755
# Form fields found:
#   - The O&G industry has four interconnected segments:
#
# Page 17:
# Characters: 5573
# Form fields found:
#   - undeveloped reserves online as PDP:
#
# Page 18:
# Characters: 5971
#
# Page 19:
# Characters: 6001
#
# Page 20:
# Characters: 5123
# Form fields found:
#   - the following areas:
#
# Page 21:
# Characters: 4951
# Form fields found:
#   - defined weaknesses:
#   - Example: Collateral Valuation ($ Million)
#   - Total collateral value:
#   - Example: Classification ($ Million)
#   - TC: Total Commitment  SM: Special Mention
#   ... and 3 more fields
#
# Page 22:
# Characters: 5621
# Form fields found:
#   - address  the  following  factors:  the  maximum  amount  that
#   - policies that include:
#   - recommended supervisory limits:
#
# Page 23:
# Characters: 5414
# Form fields found:
#   - examiners should carefully consider the following:
#   - projects include, but are not limited to:
#   - •  Changes in concept or plan: for example, a
#
# Page 24:
# Characters: 6120
#
# Page 25:
# Characters: 6014
#
# Page 26:
# Characters: 6174
# Form fields found:
#   - individual  lenders  and  borrowers:  commodity  prices  and
#
# Page 27:
# Characters: 6372
#
# Page 28:
# Characters: 6356
# Form fields found:
#   - emphasis:  collateral  control  and  renewal  practices  for
#   - resolved:
#
# Page 29:
# Characters: 6062
# Form fields found:
#   - this provision to apply:
#
# Page 30:
# Characters: 6487
# Form fields found:
#   - carryover debt came about: Did it result from the obligor’s
#   - the  following:  borrower’s  overall
#
# Page 31:
# Characters: 5928
# Form fields found:
#   - following factors: loan applications and credit checks; terms
#   - encountered in direct lease financing:
#
# Page 32:
# Characters: 6231
# Form fields found:
#   - same:  there  is  a  definite  contractual  understanding  of  the
#
# Page 33:
# Characters: 5917
# Form fields found:
#   - ways:
#   - as the following:
#
# Page 34:
# Characters: 5600
#
# Page 35:
# Characters: 6228
# Form fields found:
#   - of future net operating income:  rents (or sales), expenses,
#   - Exempt real estate-related transactions include:
#
# Page 36:
# Characters: 5894
# Form fields found:
#   - (5)  The transaction is a business loan that: (i) has a
#   - credit at the lending institution, provided that: (i)
#
# Page 37:
# Characters: 5609
# Form fields found:
#   - evaluation.  Appropriate criteria ensure that:
#
# Page 38:
# Characters: 6010
# Form fields found:
#   - preparation of an appraisal.  The appraisal must:
#
# Page 39:
# Characters: 6011
# Form fields found:
#   - reported in three different report formats:  a Self-Contained
#   - evaluations typically require that evaluations:
#
# Page 40:
# Characters: 6393
# Form fields found:
#   - originally reported values include:  the passage of time; the
#
# Page 41:
# Characters: 5660
# Form fields found:
#   - characteristics:
#
# Page 42:
# Characters: 6138
# Form fields found:
#   - if all of the following conditions are met:
#
# Page 43:
# Characters: 5813
# Form fields found:
#   - specifically include the following considerations:
#
# Page 44:
# Characters: 5618
#
# Page 45:
# Characters: 5792
#
# Page 46:
# Characters: 5515
#
# Page 47:
# Characters: 4992
#
# Page 48:
# Characters: 5168
# Form fields found:
#   - one of two reasons:
#
# Page 49:
# Characters: 5852
#
# Page 50:
# Characters: 5335
# Form fields found:
#   - applicable to a particular institution:
#
# Page 51:
# Characters: 5440
#
# Page 52:
# Characters: 5848
#
# Page 53:
# Characters: 5861
# Form fields found:
#   - on  the  basis  of  risk  to  three  categories:  Substandard;
#
# Page 54:
# Characters: 5839
#
# Page 55:
# Characters: 6288
# Form fields found:
#   - distinct groupings:  30 to 89 days past due and 90 days or
#   - provided two criteria are met:
#
# Page 56:
# Characters: 5462
# Form fields found:
#   - provided the following conditions are met:
#   - following criteria:
#
# Page 57:
# Characters: 5801
# Form fields found:
#   - should exhibit the following:
#
# Page 58:
# Characters: 5599
# Form fields found:
#   - systems typically include:
#
# Page 59:
# Characters: 6476
# Form fields found:
#   - TDRs may be divided into two broad groups: those where
#
# Page 60:
# Characters: 6575
#
# Page 61:
# Characters: 5694
# Form fields found:
#   - following items:
#
# Page 62:
# Characters: 5362
# Form fields found:
#   - institution only if:
#
# Page 63:
# Characters: 5822
#
# Page 64:
# Characters: 6327
#
# Page 65:
# Characters: 5780
# Form fields found:
#   - may be used in applicable situations:
#
# Page 66:
# Characters: 5989
#
# Page 67:
# Characters: 6406
# Form fields found:
#   - following three conditions:
#   - established  as  follows:  (1)  Creditors  with  a  perfected
#
# Page 68:
# Characters: 6081
#
# Page 69:
# Characters: 5728
# Form fields found:
#   - following:  "This is an absolute and unconditional guarantee
#
# Page 70:
# Characters: 6065
#
# Page 71:
# Characters: 6165
# Form fields found:
#   - follows:  (1) The debtor has no equity in the encumbered
#   - interests  may  be  adequately  protected:  the  creditor  may
#   - follows:  homeowner's  equity  up  to  $7,500;  automobile
#   - is not an all-inclusive list): fraudulent conveyance within 12
#   - may  file  "exceptions  to  discharge"  are:  nonpayment  of
#
# Page 72:
# Characters: 5684
# Form fields found:
#   - these  basic  limitations  on  reaffirmations:  the  agreement
#   - "avoided") if it has all of these elements: the transfer
#
# Page 73:
# Characters: 5642
# Form fields found:
#   - which  the  following  are  especially  important:  First,  the
#   - of lenders and borrowers, such as:
#   - There  are  four  phases  in  loan  syndications:    Pre-Launch,
#
# Page 74:
# Characters: 5449
# Form fields found:
#   - adjust interest rates.  Some examples are:
#   - Net Worth test: restricts the total amount of debt a borrower
#   - Current Ratio/ Quick Ratio test: measures liquidity.
#   - Capital Expenditure Limitations: generally set according to
#   - Borrowing  Base  Limitations:  lending  formula  typically
#   ... and 1 more fields
#
# Page 75:
# Characters: 5369
# Form fields found:
#   - SNCs generally include:
#   - SNCs do not include:
#
# Page 76:
# Characters: 6052
#
# Page 77:
# Characters: 6000
# Form fields found:
#   - following:
#
# Page 78:
# Characters: 5735
# Form fields found:
#   - subprime lending does not refer to: prime loans that develop
#   - following elements:
#
# Page 79:
# Characters: 5792
# Form fields found:
#   - scenarios, such as: changing attrition or prepayment rates;
#   - Agencies will expect that:
#
# Page 80:
# Characters: 6496
#
# Page 81:
# Characters: 6432
#
# Page 82:
# Characters: 6162
#
# Page 83:
# Characters: 6234
#
# Page 84:
# Characters: 5962
# Form fields found:
#   - with these prongs of the Guidelines:
#
# Page 85:
# Characters: 5863
# Form fields found:
#   - Appropriate arrangements typically:
#
# Page 86:
# Characters: 5862
#
# Page 87:
# Characters: 5827
# Form fields found:
#   - to  https://www.fdic.gov/resources/consumers/small-business-
#   - topics/sba.html  and  https://www.fdic.gov/resources/bankers/affordable-
#
# Page 88:
# Characters: 5593
#
# Page 89:
# Characters: 5685
# Form fields found:
#   - https://www.federalregister.gov/documents/2021/02/16/2021-03053/sba-
#
# Page 90:
# Characters: 6252
# Form fields found:
#   - outcomes:  (1)  full  purchase  or  payment  of  guarantee,  (2)
#
# Page 91:
# Characters: 5423
#
# Page 92:
# Characters: 6053
#
# Page 93:
# Characters: 3598
#
# Page 94:
# Characters: 0
#
# Analyzing CSV Documents:
#
# Analyzing accepted_2007_to_2018Q4.csv:
# Shape: (1011, 151)
#
# Data Quality Summary:
#
# Missing Values (%):
# - member_id: 100.0%
# - emp_title: 4.3%
# - emp_length: 4.2%
# - desc: 100.0%
# - title: 3.5%
# - mths_since_last_delinq: 50.0%
# - mths_since_last_record: 81.4%
# - next_pymnt_d: 87.3%
# - mths_since_last_major_derog: 71.5%
# - annual_inc_joint: 99.2%
# - dti_joint: 99.2%
# - verification_status_joint: 99.2%
# - mths_since_rcnt_il: 1.9%
# - il_util: 12.1%
# - bc_open_to_buy: 0.8%
# - bc_util: 0.9%
# - mo_sin_old_il_acct: 1.9%
# - mths_since_recent_bc: 0.8%
# - mths_since_recent_bc_dlq: 75.4%
# - mths_since_recent_inq: 11.6%
# - mths_since_recent_revol_delinq: 66.2%
# - num_tl_120dpd_2m: 6.0%
# - percent_bc_gt_75: 0.8%
# - revol_bal_joint: 100.0%
# - sec_app_fico_range_low: 100.0%
# - sec_app_fico_range_high: 100.0%
# - sec_app_earliest_cr_line: 100.0%
# - sec_app_inq_last_6mths: 100.0%
# - sec_app_mort_acc: 100.0%
# - sec_app_open_acc: 100.0%
# - sec_app_revol_util: 100.0%
# - sec_app_open_act_il: 100.0%
# - sec_app_num_rev_accts: 100.0%
# - sec_app_chargeoff_within_12_mths: 100.0%
# - sec_app_collections_12_mths_ex_med: 100.0%
# - sec_app_mths_since_last_major_derog: 100.0%
# - hardship_type: 99.0%
# - hardship_reason: 99.0%
# - hardship_status: 99.0%
# - deferral_term: 99.0%
# - hardship_amount: 99.0%
# - hardship_start_date: 99.0%
# - hardship_end_date: 99.0%
# - payment_plan_start_date: 99.0%
# - hardship_length: 99.0%
# - hardship_dpd: 99.0%
# - hardship_loan_status: 99.0%
# - orig_projected_additional_accrued_interest: 99.1%
# - hardship_payoff_balance_amount: 99.0%
# - hardship_last_payment_amount: 99.0%
# - debt_settlement_flag_date: 97.8%
# - settlement_status: 97.8%
# - settlement_date: 97.8%
# - settlement_amount: 97.8%
# - settlement_percentage: 97.8%
# - settlement_term: 97.8%
#
# Numeric Columns Statistics:
#
# id:
#   mean: 68296587.34
#   std: 2163680.07
#   min: 699575.00
#   max: 68617057.00
#   zeros_pct: 0.00
#
# member_id:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# loan_amnt:
#   mean: 15582.99
#   std: 8674.77
#   min: 1000.00
#   max: 35000.00
#   zeros_pct: 0.00
#
# funded_amnt:
#   mean: 15582.99
#   std: 8674.77
#   min: 1000.00
#   max: 35000.00
#   zeros_pct: 0.00
#
# funded_amnt_inv:
#   mean: 15582.99
#   std: 8674.77
#   min: 1000.00
#   max: 35000.00
#   zeros_pct: 0.00
#
# int_rate:
#   mean: 12.03
#   std: 4.39
#   min: 5.32
#   max: 28.49
#   zeros_pct: 0.00
#
# installment:
#   mean: 451.15
#   std: 249.46
#   min: 32.97
#   max: 1252.56
#   zeros_pct: 0.00
#
# annual_inc:
#   mean: 79912.00
#   std: 41631.42
#   min: 13000.00
#   max: 450000.00
#   zeros_pct: 0.00
#
# desc:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# dti:
#   mean: 19.41
#   std: 8.36
#   min: 0.63
#   max: 46.71
#   zeros_pct: 0.00
#
# delinq_2yrs:
#   mean: 0.33
#   std: 0.91
#   min: 0.00
#   max: 15.00
#   zeros_pct: 79.33
#
# fico_range_low:
#   mean: 699.43
#   std: 33.16
#   min: 660.00
#   max: 845.00
#   zeros_pct: 0.00
#
# fico_range_high:
#   mean: 703.43
#   std: 33.17
#   min: 664.00
#   max: 850.00
#   zeros_pct: 0.00
#
# inq_last_6mths:
#   mean: 0.59
#   std: 0.91
#   min: 0.00
#   max: 5.00
#   zeros_pct: 60.53
#
# mths_since_last_delinq:
#   mean: 32.80
#   std: 20.70
#   min: 0.00
#   max: 82.00
#   zeros_pct: 0.30
#
# mths_since_last_record:
#   mean: 62.24
#   std: 23.85
#   min: 1.00
#   max: 117.00
#   zeros_pct: 0.00
#
# open_acc:
#   mean: 12.54
#   std: 5.60
#   min: 2.00
#   max: 46.00
#   zeros_pct: 0.00
#
# pub_rec:
#   mean: 0.22
#   std: 0.54
#   min: 0.00
#   max: 5.00
#   zeros_pct: 81.40
#
# revol_bal:
#   mean: 18364.27
#   std: 20328.20
#   min: 0.00
#   max: 290575.00
#   zeros_pct: 0.10
#
# revol_util:
#   mean: 50.23
#   std: 23.32
#   min: 0.00
#   max: 102.40
#   zeros_pct: 0.20
#
# total_acc:
#   mean: 26.42
#   std: 12.16
#   min: 4.00
#   max: 89.00
#   zeros_pct: 0.00
#
# out_prncp:
#   mean: 1111.15
#   std: 3201.84
#   min: 0.00
#   max: 16938.77
#   zeros_pct: 87.34
#
# out_prncp_inv:
#   mean: 1111.15
#   std: 3201.84
#   min: 0.00
#   max: 16938.77
#   zeros_pct: 87.34
#
# total_pymnt:
#   mean: 15992.53
#   std: 10079.54
#   min: 408.22
#   max: 48259.60
#   zeros_pct: 0.00
#
# total_pymnt_inv:
#   mean: 15992.53
#   std: 10079.54
#   min: 408.22
#   max: 48259.60
#   zeros_pct: 0.00
#
# total_rec_prncp:
#   mean: 12993.09
#   std: 8633.45
#   min: 0.00
#   max: 35000.00
#   zeros_pct: 0.10
#
# total_rec_int:
#   mean: 2844.62
#   std: 2822.80
#   min: 0.00
#   max: 18502.04
#   zeros_pct: 0.10
#
# total_rec_late_fee:
#   mean: 2.73
#   std: 18.71
#   min: 0.00
#   max: 430.12
#   zeros_pct: 94.86
#
# recoveries:
#   mean: 152.09
#   std: 743.95
#   min: 0.00
#   max: 13403.00
#   zeros_pct: 90.50
#
# collection_recovery_fee:
#   mean: 25.13
#   std: 129.56
#   min: 0.00
#   max: 2412.54
#   zeros_pct: 90.50
#
# last_pymnt_amnt:
#   mean: 4798.36
#   std: 6918.69
#   min: 0.14
#   max: 34484.92
#   zeros_pct: 0.00
#
# last_fico_range_high:
#   mean: 687.29
#   std: 77.56
#   min: 499.00
#   max: 839.00
#   zeros_pct: 0.00
#
# last_fico_range_low:
#   mean: 672.52
#   std: 123.68
#   min: 0.00
#   max: 835.00
#   zeros_pct: 2.18
#
# collections_12_mths_ex_med:
#   mean: 0.01
#   std: 0.12
#   min: 0.00
#   max: 1.00
#   zeros_pct: 98.62
#
# mths_since_last_major_derog:
#   mean: 43.30
#   std: 20.50
#   min: 0.00
#   max: 86.00
#   zeros_pct: 0.10
#
# policy_code:
#   mean: 1.00
#   std: 0.00
#   min: 1.00
#   max: 1.00
#   zeros_pct: 0.00
#
# annual_inc_joint:
#   mean: 103253.60
#   std: 40953.06
#   min: 61366.44
#   max: 192000.00
#   zeros_pct: 0.00
#
# dti_joint:
#   mean: 19.43
#   std: 4.53
#   min: 13.85
#   max: 25.44
#   zeros_pct: 0.00
#
# acc_now_delinq:
#   mean: 0.00
#   std: 0.07
#   min: 0.00
#   max: 1.00
#   zeros_pct: 99.51
#
# tot_coll_amt:
#   mean: 225.69
#   std: 3287.66
#   min: 0.00
#   max: 102841.00
#   zeros_pct: 85.16
#
# tot_cur_bal:
#   mean: 162928.32
#   std: 154712.78
#   min: 476.00
#   max: 1237015.00
#   zeros_pct: 0.00
#
# open_acc_6m:
#   mean: 1.18
#   std: 1.26
#   min: 0.00
#   max: 9.00
#   zeros_pct: 36.00
#
# open_act_il:
#   mean: 2.96
#   std: 2.98
#   min: 0.00
#   max: 21.00
#   zeros_pct: 10.09
#
# open_il_12m:
#   mean: 0.75
#   std: 0.93
#   min: 0.00
#   max: 6.00
#   zeros_pct: 49.95
#
# open_il_24m:
#   mean: 1.65
#   std: 1.55
#   min: 0.00
#   max: 9.00
#   zeros_pct: 25.62
#
# mths_since_rcnt_il:
#   mean: 21.35
#   std: 30.22
#   min: 0.00
#   max: 338.00
#   zeros_pct: 0.10
#
# total_bal_il:
#   mean: 37647.74
#   std: 41517.98
#   min: 0.00
#   max: 352033.00
#   zeros_pct: 9.79
#
# il_util:
#   mean: 70.85
#   std: 22.55
#   min: 0.00
#   max: 132.00
#   zeros_pct: 0.59
#
# open_rv_12m:
#   mean: 1.49
#   std: 1.57
#   min: 0.00
#   max: 12.00
#   zeros_pct: 30.66
#
# open_rv_24m:
#   mean: 3.03
#   std: 2.65
#   min: 0.00
#   max: 24.00
#   zeros_pct: 12.46
#
# max_bal_bc:
#   mean: 6334.87
#   std: 5866.30
#   min: 0.00
#   max: 100973.00
#   zeros_pct: 1.38
#
# all_util:
#   mean: 59.35
#   std: 19.93
#   min: 5.00
#   max: 127.00
#   zeros_pct: 0.00
#
# total_rev_hi_lim:
#   mean: 38340.60
#   std: 34670.64
#   min: 1700.00
#   max: 358500.00
#   zeros_pct: 0.00
#
# inq_fi:
#   mean: 0.92
#   std: 1.47
#   min: 0.00
#   max: 16.00
#   zeros_pct: 54.50
#
# total_cu_tl:
#   mean: 1.64
#   std: 2.72
#   min: 0.00
#   max: 18.00
#   zeros_pct: 51.34
#
# inq_last_12m:
#   mean: 2.29
#   std: 2.50
#   min: 0.00
#   max: 20.00
#   zeros_pct: 25.52
#
# acc_open_past_24mths:
#   mean: 4.97
#   std: 3.24
#   min: 0.00
#   max: 24.00
#   zeros_pct: 3.76
#
# avg_cur_bal:
#   mean: 15142.15
#   std: 17237.12
#   min: 98.00
#   max: 219353.00
#   zeros_pct: 0.00
#
# bc_open_to_buy:
#   mean: 12299.77
#   std: 18610.91
#   min: 0.00
#   max: 263953.00
#   zeros_pct: 1.78
#
# bc_util:
#   mean: 57.79
#   std: 27.32
#   min: 0.00
#   max: 106.20
#   zeros_pct: 0.59
#
# chargeoff_within_12_mths:
#   mean: 0.01
#   std: 0.09
#   min: 0.00
#   max: 1.00
#   zeros_pct: 99.11
#
# delinq_amnt:
#   mean: 0.82
#   std: 21.76
#   min: 0.00
#   max: 687.00
#   zeros_pct: 99.51
#
# mo_sin_old_il_acct:
#   mean: 127.66
#   std: 50.52
#   min: 1.00
#   max: 388.00
#   zeros_pct: 0.00
#
# mo_sin_old_rev_tl_op:
#   mean: 191.36
#   std: 95.28
#   min: 7.00
#   max: 707.00
#   zeros_pct: 0.00
#
# mo_sin_rcnt_rev_tl_op:
#   mean: 12.30
#   std: 17.46
#   min: 0.00
#   max: 180.00
#   zeros_pct: 4.25
#
# mo_sin_rcnt_tl:
#   mean: 7.01
#   std: 9.50
#   min: 0.00
#   max: 180.00
#   zeros_pct: 4.45
#
# mort_acc:
#   mean: 1.89
#   std: 2.01
#   min: 0.00
#   max: 12.00
#   zeros_pct: 33.83
#
# mths_since_recent_bc:
#   mean: 22.17
#   std: 29.18
#   min: 0.00
#   max: 297.00
#   zeros_pct: 1.19
#
# mths_since_recent_bc_dlq:
#   mean: 35.98
#   std: 22.23
#   min: 0.00
#   max: 87.00
#   zeros_pct: 0.10
#
# mths_since_recent_inq:
#   mean: 6.39
#   std: 5.82
#   min: 0.00
#   max: 23.00
#   zeros_pct: 11.77
#
# mths_since_recent_revol_delinq:
#   mean: 32.73
#   std: 21.39
#   min: 0.00
#   max: 87.00
#   zeros_pct: 0.20
#
# num_accts_ever_120_pd:
#   mean: 0.47
#   std: 1.35
#   min: 0.00
#   max: 17.00
#   zeros_pct: 78.34
#
# num_actv_bc_tl:
#   mean: 3.75
#   std: 2.24
#   min: 0.00
#   max: 18.00
#   zeros_pct: 1.38
#
# num_actv_rev_tl:
#   mean: 5.87
#   std: 3.33
#   min: 0.00
#   max: 28.00
#   zeros_pct: 0.10
#
# num_bc_sats:
#   mean: 4.95
#   std: 2.95
#   min: 0.00
#   max: 21.00
#   zeros_pct: 0.79
#
# num_bc_tl:
#   mean: 8.33
#   std: 4.86
#   min: 0.00
#   max: 44.00
#   zeros_pct: 0.30
#
# num_il_tl:
#   mean: 8.89
#   std: 7.27
#   min: 0.00
#   max: 59.00
#   zeros_pct: 1.88
#
# num_op_rev_tl:
#   mean: 8.76
#   std: 4.68
#   min: 1.00
#   max: 30.00
#   zeros_pct: 0.00
#
# num_rev_accts:
#   mean: 15.34
#   std: 8.41
#   min: 2.00
#   max: 80.00
#   zeros_pct: 0.00
#
# num_rev_tl_bal_gt_0:
#   mean: 5.91
#   std: 3.32
#   min: 0.00
#   max: 28.00
#   zeros_pct: 0.10
#
# num_sats:
#   mean: 12.49
#   std: 5.59
#   min: 2.00
#   max: 46.00
#   zeros_pct: 0.00
#
# num_tl_120dpd_2m:
#   mean: 0.00
#   std: 0.00
#   min: 0.00
#   max: 0.00
#   zeros_pct: 93.97
#
# num_tl_30dpd:
#   mean: 0.00
#   std: 0.06
#   min: 0.00
#   max: 1.00
#   zeros_pct: 99.60
#
# num_tl_90g_dpd_24m:
#   mean: 0.09
#   std: 0.52
#   min: 0.00
#   max: 12.00
#   zeros_pct: 94.07
#
# num_tl_op_past_12m:
#   mean: 2.38
#   std: 1.92
#   min: 0.00
#   max: 12.00
#   zeros_pct: 14.24
#
# pct_tl_nvr_dlq:
#   mean: 94.19
#   std: 8.99
#   min: 39.00
#   max: 100.00
#   zeros_pct: 0.00
#
# percent_bc_gt_75:
#   mean: 41.32
#   std: 35.76
#   min: 0.00
#   max: 100.00
#   zeros_pct: 27.79
#
# pub_rec_bankruptcies:
#   mean: 0.13
#   std: 0.35
#   min: 0.00
#   max: 2.00
#   zeros_pct: 87.73
#
# tax_liens:
#   mean: 0.06
#   std: 0.31
#   min: 0.00
#   max: 5.00
#   zeros_pct: 95.85
#
# tot_hi_cred_lim:
#   mean: 202671.29
#   std: 171219.62
#   min: 5000.00
#   max: 1377228.00
#   zeros_pct: 0.00
#
# total_bal_ex_mort:
#   mean: 56506.03
#   std: 48252.20
#   min: 476.00
#   max: 500115.00
#   zeros_pct: 0.00
#
# total_bc_limit:
#   mean: 25299.20
#   std: 24842.58
#   min: 0.00
#   max: 281300.00
#   zeros_pct: 0.79
#
# total_il_high_credit_limit:
#   mean: 47953.54
#   std: 43935.42
#   min: 0.00
#   max: 347057.00
#   zeros_pct: 9.79
#
# revol_bal_joint:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_fico_range_low:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_fico_range_high:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_earliest_cr_line:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_inq_last_6mths:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_mort_acc:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_open_acc:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_revol_util:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_open_act_il:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_num_rev_accts:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_chargeoff_within_12_mths:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_collections_12_mths_ex_med:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# sec_app_mths_since_last_major_derog:
#   mean: nan
#   std: nan
#   min: nan
#   max: nan
#   zeros_pct: 0.00
#
# deferral_term:
#   mean: 3.00
#   std: 0.00
#   min: 3.00
#   max: 3.00
#   zeros_pct: 0.00
#
# hardship_amount:
#   mean: 118.75
#   std: 99.00
#   min: 21.63
#   max: 328.79
#   zeros_pct: 0.00
#
# hardship_length:
#   mean: 3.00
#   std: 0.00
#   min: 3.00
#   max: 3.00
#   zeros_pct: 0.00
#
# hardship_dpd:
#   mean: 9.50
#   std: 11.29
#   min: 0.00
#   max: 27.00
#   zeros_pct: 0.49
#
# orig_projected_additional_accrued_interest:
#   mean: 380.18
#   std: 304.63
#   min: 64.89
#   max: 986.37
#   zeros_pct: 0.00
#
# hardship_payoff_balance_amount:
#   mean: 11180.14
#   std: 8451.54
#   min: 1755.40
#   max: 26990.90
#   zeros_pct: 0.00
#
# hardship_last_payment_amount:
#   mean: 193.19
#   std: 264.08
#   min: 0.71
#   max: 756.87
#   zeros_pct: 0.00
#
# settlement_amount:
#   mean: 4677.73
#   std: 3424.72
#   min: 303.00
#   max: 13403.00
#   zeros_pct: 0.00
#
# settlement_percentage:
#   mean: 46.68
#   std: 3.89
#   min: 44.93
#   max: 60.01
#   zeros_pct: 0.00
#
# settlement_term:
#   mean: 12.09
#   std: 8.37
#   min: 1.00
#   max: 24.00
#   zeros_pct: 0.00
#
# Categorical Columns:
#
# term:
#   Unique values: 2
#   Value distribution:
#     -  36 months: 694
#     -  60 months: 317
#
# grade:
#   Unique values: 7
#   Value distribution:
#     - B: 297
#     - C: 276
#     - A: 215
#     - D: 140
#     - E: 61
#
# sub_grade:
#   Unique values: 33
#   Value distribution:
#     - A1: 71
#     - C2: 70
#     - B2: 67
#     - B4: 65
#     - C1: 63
#
# emp_title:
#   Unique values: 748
#   Value distribution:
#     - Teacher: 37
#     - Manager: 13
#     - Sales: 9
#     - General Manager: 9
#     - Registered Nurse: 8
#
# emp_length:
#   Unique values: 11
#   Value distribution:
#     - 10+ years: 363
#     - 2 years: 102
#     - < 1 year: 90
#     - 3 years: 88
#     - 1 year: 68
#
# home_ownership:
#   Unique values: 3
#   Value distribution:
#     - MORTGAGE: 557
#     - RENT: 327
#     - OWN: 127
#
# verification_status:
#   Unique values: 3
#   Value distribution:
#     - Not Verified: 459
#     - Source Verified: 333
#     - Verified: 219
#
# issue_d:
#   Unique values: 1
#   Value distribution:
#     - Dec-2015: 1011
#
# loan_status:
#   Unique values: 5
#   Value distribution:
#     - Fully Paid: 738
#     - Charged Off: 145
#     - Current: 122
#     - Late (31-120 days): 5
#     - In Grace Period: 1
#
# pymnt_plan:
#   Unique values: 1
#   Value distribution:
#     - n: 1011
#
# url:
#   Unique values: 1011
#   Value distribution:
#     - https://lendingclub.com/browse/loanDetail.action?loan_id=68407277: 1
#     - https://lendingclub.com/browse/loanDetail.action?loan_id=68606744: 1
#     - https://lendingclub.com/browse/loanDetail.action?loan_id=68566440: 1
#     - https://lendingclub.com/browse/loanDetail.action?loan_id=68426365: 1
#     - https://lendingclub.com/browse/loanDetail.action?loan_id=68415164: 1
#
# purpose:
#   Unique values: 11
#   Value distribution:
#     - debt_consolidation: 584
#     - credit_card: 261
#     - home_improvement: 59
#     - other: 45
#     - major_purchase: 23
#
# title:
#   Unique values: 11
#   Value distribution:
#     - Debt consolidation: 567
#     - Credit card refinancing: 252
#     - Home improvement: 56
#     - Other: 40
#     - Major purchase: 23
#
# zip_code:
#   Unique values: 424
#   Value distribution:
#     - 300xx: 17
#     - 770xx: 15
#     - 117xx: 14
#     - 945xx: 12
#     - 331xx: 10
#
# addr_state:
#   Unique values: 47
#   Value distribution:
#     - CA: 107
#     - TX: 84
#     - NY: 77
#     - FL: 69
#     - OH: 43
#
# earliest_cr_line:
#   Unique values: 329
#   Value distribution:
#     - Aug-2003: 14
#     - Nov-1994: 14
#     - Sep-2002: 13
#     - Jun-2001: 12
#     - Oct-1999: 11
#
# initial_list_status:
#   Unique values: 2
#   Value distribution:
#     - w: 968
#     - f: 43
#
# last_pymnt_d:
#   Unique values: 39
#   Value distribution:
#     - Jan-2019: 153
#     - Feb-2019: 105
#     - Mar-2019: 47
#     - Dec-2018: 39
#     - Jan-2017: 29
#
# next_pymnt_d:
#   Unique values: 1
#   Value distribution:
#     - Apr-2019: 128
#
# last_credit_pull_d:
#   Unique values: 38
#   Value distribution:
#     - Mar-2019: 449
#     - Dec-2018: 83
#     - Jan-2019: 66
#     - Feb-2019: 64
#     - Jul-2018: 28
#
# application_type:
#   Unique values: 2
#   Value distribution:
#     - Individual: 1003
#     - Joint App: 8
#
# verification_status_joint:
#   Unique values: 1
#   Value distribution:
#     - Not Verified: 8
#
# hardship_flag:
#   Unique values: 1
#   Value distribution:
#     - N: 1011
#
# hardship_type:
#   Unique values: 1
#   Value distribution:
#     - INTEREST ONLY-3 MONTHS DEFERRAL: 10
#
# hardship_reason:
#   Unique values: 4
#   Value distribution:
#     - NATURAL_DISASTER: 7
#     - DIVORCE: 1
#     - EXCESSIVE_OBLIGATIONS: 1
#     - DISABILITY: 1
#
# hardship_status:
#   Unique values: 2
#   Value distribution:
#     - COMPLETED: 9
#     - BROKEN: 1
#
# hardship_start_date:
#   Unique values: 4
#   Value distribution:
#     - Sep-2017: 7
#     - Jul-2017: 1
#     - Sep-2018: 1
#     - Dec-2017: 1
#
# hardship_end_date:
#   Unique values: 5
#   Value distribution:
#     - Dec-2017: 5
#     - Nov-2017: 2
#     - Oct-2017: 1
#     - Dec-2018: 1
#     - Feb-2018: 1
#
# payment_plan_start_date:
#   Unique values: 5
#   Value distribution:
#     - Sep-2017: 5
#     - Oct-2017: 2
#     - Aug-2017: 1
#     - Sep-2018: 1
#     - Dec-2017: 1
#
# hardship_loan_status:
#   Unique values: 4
#   Value distribution:
#     - Current: 5
#     - Late (16-30 days): 3
#     - Late (31-120 days): 1
#     - In Grace Period: 1
#
# disbursement_method:
#   Unique values: 1
#   Value distribution:
#     - Cash: 1011
#
# debt_settlement_flag:
#   Unique values: 2
#   Value distribution:
#     - N: 989
#     - Y: 22
#
# debt_settlement_flag_date:
#   Unique values: 12
#   Value distribution:
#     - May-2018: 5
#     - Jul-2018: 3
#     - Feb-2019: 2
#     - Nov-2018: 2
#     - Dec-2018: 2
#
# settlement_status:
#   Unique values: 3
#   Value distribution:
#     - COMPLETE: 11
#     - ACTIVE: 7
#     - BROKEN: 4
#
# settlement_date:
#   Unique values: 15
#   Value distribution:
#     - May-2018: 3
#     - Sep-2017: 2
#     - Nov-2017: 2
#     - Jan-2018: 2
#     - Jan-2019: 2
#
# Potential Data Quality Issues:
# - id might be an ID column (100.0% unique values)
# - High outliers in id: 10.7% of values
# - High missing values in member_id: 100.0%
# - url might be an ID column (100.0% unique values)
# - High missing values in desc: 100.0%
# - High outliers in delinq_2yrs: 20.7% of values
# - High missing values in mths_since_last_delinq: 50.0%
# - High missing values in mths_since_last_record: 81.4%
# - High outliers in pub_rec: 18.6% of values
# - revol_bal might be an ID column (98.2% unique values)
# - High outliers in out_prncp: 12.7% of values
# - High outliers in out_prncp_inv: 12.7% of values
# - total_pymnt might be an ID column (98.5% unique values)
# - total_pymnt_inv might be an ID column (98.4% unique values)
# - total_rec_int might be an ID column (98.7% unique values)
# - High outliers in total_rec_int: 7.2% of values
# - High outliers in total_rec_late_fee: 5.1% of values
# - High outliers in recoveries: 9.5% of values
# - High outliers in collection_recovery_fee: 9.5% of values
# - last_pymnt_amnt might be an ID column (95.8% unique values)
# - High outliers in last_pymnt_amnt: 7.1% of values
# - High missing values in next_pymnt_d: 87.3%
# - High missing values in mths_since_last_major_derog: 71.5%
# - High missing values in annual_inc_joint: 99.2%
# - High missing values in dti_joint: 99.2%
# - High missing values in verification_status_joint: 99.2%
# - High outliers in tot_coll_amt: 14.8% of values
# - tot_cur_bal might be an ID column (99.8% unique values)
# - High outliers in open_act_il: 5.8% of values
# - High outliers in mths_since_rcnt_il: 9.7% of values
# - High outliers in total_bal_il: 5.7% of values
# - max_bal_bc might be an ID column (95.5% unique values)
# - High outliers in total_rev_hi_lim: 5.6% of values
# - High outliers in inq_fi: 11.3% of values
# - High outliers in total_cu_tl: 9.6% of values
# - avg_cur_bal might be an ID column (98.3% unique values)
# - High outliers in avg_cur_bal: 5.2% of values
# - bc_open_to_buy might be an ID column (94.7% unique values)
# - High outliers in bc_open_to_buy: 8.1% of values
# - High outliers in mo_sin_old_il_acct: 7.9% of values
# - High outliers in mo_sin_rcnt_rev_tl_op: 7.6% of values
# - High outliers in mo_sin_rcnt_tl: 5.2% of values
# - High outliers in mths_since_recent_bc: 7.4% of values
# - High missing values in mths_since_recent_bc_dlq: 75.4%
# - High missing values in mths_since_recent_revol_delinq: 66.2%
# - High outliers in num_accts_ever_120_pd: 21.7% of values
# - High outliers in num_actv_rev_tl: 5.8% of values
# - High outliers in num_tl_90g_dpd_24m: 5.9% of values
# - High outliers in pct_tl_nvr_dlq: 7.4% of values
# - High outliers in pub_rec_bankruptcies: 12.3% of values
# - tot_hi_cred_lim might be an ID column (99.3% unique values)
# - total_bal_ex_mort might be an ID column (99.3% unique values)
# - High missing values in revol_bal_joint: 100.0%
# - High missing values in sec_app_fico_range_low: 100.0%
# - High missing values in sec_app_fico_range_high: 100.0%
# - High missing values in sec_app_earliest_cr_line: 100.0%
# - High missing values in sec_app_inq_last_6mths: 100.0%
# - High missing values in sec_app_mort_acc: 100.0%
# - High missing values in sec_app_open_acc: 100.0%
# - High missing values in sec_app_revol_util: 100.0%
# - High missing values in sec_app_open_act_il: 100.0%
# - High missing values in sec_app_num_rev_accts: 100.0%
# - High missing values in sec_app_chargeoff_within_12_mths: 100.0%
# - High missing values in sec_app_collections_12_mths_ex_med: 100.0%
# - High missing values in sec_app_mths_since_last_major_derog: 100.0%
# - High missing values in hardship_type: 99.0%
# - High missing values in hardship_reason: 99.0%
# - High missing values in hardship_status: 99.0%
# - High missing values in deferral_term: 99.0%
# - High missing values in hardship_amount: 99.0%
# - High missing values in hardship_start_date: 99.0%
# - High missing values in hardship_end_date: 99.0%
# - High missing values in payment_plan_start_date: 99.0%
# - High missing values in hardship_length: 99.0%
# - High missing values in hardship_dpd: 99.0%
# - High missing values in hardship_loan_status: 99.0%
# - High missing values in orig_projected_additional_accrued_interest: 99.1%
# - High missing values in hardship_payoff_balance_amount: 99.0%
# - High missing values in hardship_last_payment_amount: 99.0%
# - High missing values in debt_settlement_flag_date: 97.8%
# - High missing values in settlement_status: 97.8%
# - High missing values in settlement_date: 97.8%
# - High missing values in settlement_amount: 97.8%
# - High missing values in settlement_percentage: 97.8%
# - High missing values in settlement_term: 97.8%
#
# Analyzing rejected_2007_to_2018Q4.csv:
# Shape: (1005, 9)
#
# Data Quality Summary:
#
# Missing Values (%):
# - Risk_Score: 0.6%
#
# Numeric Columns Statistics:
#
# Amount Requested:
#   mean: 7192.71
#   std: 6786.59
#   min: 500.00
#   max: 25000.00
#   zeros_pct: 0.00
#
# Risk_Score:
#   mean: 539.55
#   std: 141.37
#   min: 0.00
#   max: 789.00
#   zeros_pct: 4.68
#
# Policy Code:
#   mean: 0.00
#   std: 0.00
#   min: 0.00
#   max: 0.00
#   zeros_pct: 100.00
#
# Categorical Columns:
#
# Application Date:
#   Unique values: 117
#   Value distribution:
#     - 2007-09-13: 24
#     - 2007-06-25: 23
#     - 2007-09-14: 22
#     - 2007-06-24: 19
#     - 2007-08-28: 17
#
# Loan Title:
#   Unique values: 1005
#   Value distribution:
#     - Wedding Covered but No Honeymoon: 1
#     - MTM21o83: 1
#     - KH: 1
#     - oneals: 1
#     - videoscan23: 1
#
# Debt-To-Income Ratio:
#   Unique values: 784
#   Value distribution:
#     - 0%: 114
#     - 10%: 25
#     - 100%: 5
#     - 1.84%: 5
#     - 2.4%: 4
#
# Zip Code:
#   Unique values: 409
#   Value distribution:
#     - 100xx: 24
#     - 112xx: 19
#     - 333xx: 17
#     - 331xx: 15
#     - 300xx: 14
#
# State:
#   Unique values: 46
#   Value distribution:
#     - NY: 107
#     - FL: 98
#     - TX: 71
#     - OH: 50
#     - GA: 47
#
# Employment Length:
#   Unique values: 11
#   Value distribution:
#     - < 1 year: 365
#     - 1 year: 197
#     - 2 years: 123
#     - 3 years: 82
#     - 10+ years: 74
#
# Potential Data Quality Issues:
# - High outliers in Amount Requested: 6.8% of values
# - Loan Title might be an ID column (100.0% unique values)
#
# Verifying processed data...
#
# Currently processed files:
# - data\raw\loan_applications\Personal-Loan-Application-with-Disclosures-Fill-Form.pdf
# - data\raw\loan_applications\URLA_2019_Borrower_v28.pdf
# - data\raw\policy_documents\mill-citiescommunity-investments-loan-policies.pdf
# - data\raw\policy_documents\section3-2.pdf
# - data\raw\training_data\accepted_2007_to_2018Q4.csv
# - data\raw\training_data\rejected_2007_to_2018Q4.csv
#
# ChromaDB collection info:
# Total documents: 8101
#
# Document types distribution:
# - pdf: 1939 chunks
# - csv: 6162 chunks
#
# Source files distribution:
# - Personal-Loan-Application-with-Disclosures-Fill-Form.pdf: 26 chunks
# - URLA_2019_Borrower_v28.pdf: 64 chunks
# - mill-citiescommunity-investments-loan-policies.pdf: 163 chunks
# - section3-2.pdf: 1686 chunks
# - accepted_2007_to_2018Q4.csv: 5152 chunks
# - rejected_2007_to_2018Q4.csv: 1010 chunks
#
# Processing complete. Check the analysis output above for data quality issues.

# %%
def view_pdf_data(file_path: Path):
    """View extracted data from a PDF document"""
    try:
        # Extract text using the most reliable method
        from pdfminer.high_level import extract_text
        from pdfplumber import open as pdfplumber_open
        from PyPDF2 import PdfReader
        
        print(f"\nAnalyzing {file_path.name}:")
        
        # Try multiple extraction methods
        methods = {
            'pdfminer': extract_text(file_path),
            'pdfplumber': "\n".join(page.extract_text() for page in pdfplumber_open(file_path).pages),
            'PyPDF2': "\n".join(page.extract_text() for page in PdfReader(file_path).pages)
        }
        
        # Choose the method with most content
        best_text = max(methods.values(), key=len)
        
        if not best_text.strip():
            print("No text extracted. Attempting OCR...")
            from pytesseract import image_to_string
            from pdf2image import convert_from_path
            
            images = convert_from_path(file_path)
            best_text = "\n".join(image_to_string(img) for img in images)
            
            if not best_text.strip():
                print("OCR failed to extract text")
                return None
        
        # Display extracted data
        print("\nExtracted Text Preview:")
        print(best_text[:2000])  # Show first 2000 characters
        
        # Analyze document structure
        print("\nDocument Structure Analysis:")
        lines = best_text.split('\n')
        sections = [line.strip() for line in lines if line.strip().isupper() or ':' in line]
        
        print("\nDetected Sections/Fields:")
        for i, section in enumerate(sections[:20]):  # Show first 20 sections
            print(f"{i+1}. {section}")
            if i == 19:
                print("... (truncated)")
        
        # Save extracted data
        output_file = file_path.with_suffix('.txt')
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write(best_text)
        print(f"\nFull text saved to: {output_file}")
        
        return best_text
        
    except Exception as e:
        print(f"Error processing {file_path}: {str(e)}")
        return None

# Process all PDFs in directory
pdf_dir = Path('data/raw')  # Update with your directory
for pdf_file in pdf_dir.rglob('*.pdf'):
    print("\n" + "="*50)
    print(f"Processing: {pdf_file.name}")
    print("="*50)
    extracted_data = view_pdf_data(pdf_file)
    
    if extracted_data:
        print("\nExtraction successful!")
    else:
        print("\nExtraction failed for this document")
# Out:
# ==================================================
# Processing: Personal-Loan-Application-with-Disclosures-Fill-Form.pdf
# ==================================================
#
# Analyzing Personal-Loan-Application-with-Disclosures-Fill-Form.pdf:
#
# Extracted Text Preview:
# PERSONAL  LOAN  APPLICATION
# [SEE REVERSE SIDE FOR IMPORTANT INFORMATION ABOUT PROCEDURES FOR OPENING A NEW
#
# ACCOUNT]
#
# IMPORTANT: Read these Directions before completing this Application. Check the Appropriate Box.
#
# you are applying for individual credit or an individual account, in your own name, and are relying on your own income or assets and not the income or assets of another person as the basis for repayment
#
# fI
# of the credit requested, complete only Sections A-D. If the requested credit or account is to be secured, also complete the first part of Section F.
#
# If you are applying for joint credit with another person or for a joint account or an account that you and another person will use, complete all Sections, providing information in Section E about the joint
# applicant.
#
# We intend to apply for joint credit.
#
# Applicant
#
# _____________________________________________________
#
# Co-Applicant
#
# ___________________________________________________
#
# If you are applying for individual credit or an individual account, but are relying on income from alimony, child support, or separate maintenance or on the income or assets of another person as the basis for
# repayment of the credit requested, complete all Sections to the extent possible, providing information in Section E about the person on whose alimony, support, or maintenance payments or income or assets
# are relying.
#
# you
#
# NAME
#
# (Please  print  full
#
# name)
#
# PRESENT  STREET
#
# ADDRESS
#
# CITY, STATE AND
#
# ZIP
#
# SECTION A -
# PHONE
#
# HOME
#
# APPLICANT
# CELL
# PHONE
#
# AMOUNT  OF  LOAN
#
# REQUESTED
#
# REQUESTED MOS. TO
#
# PAY
#
# HOW LONG AT THIS
#
# ADDRESS:
#
# PURPOSE OF
#
# LOAN
#
# E-MAIL
#
# ADDRESS:
#
# COLLATERAL OFFERED AND HOW
#
# OWNED
#
# IMMEDIATE PREVIOUS
#
# ADDRESS
#
# HOW LONG AT THIS
#
# ADDRESS:
#
# CITY AND
#
# STATE
#
# ZIP
#
# Have you ever applied to us for a
#
# loan?
#
#        Yes
#
#    No
#
# If Yes,
#
# When?
#
# SOCIAL SECURITY
#
# NUMBER
#
# DRIVERS LICENSE NUMBER -
#
# STATE
#
# BIRTH
#
# DATE
#
# NO. OF
#
# DEPENDENTS - LIST BY
#
# AGE
#
# NAME,  ADDRESS  AND  RELATIONSHIP
#
# Document Structure Analysis:
#
# Detected Sections/Fields:
# 1. PERSONAL  LOAN  APPLICATION
# 2. [SEE REVERSE SIDE FOR IMPORTANT INFORMATION ABOUT PROCEDURES FOR OPENING A NEW
# 3. ACCOUNT]
# 4. IMPORTANT: Read these Directions before completing this Application. Check the Appropriate Box.
# 5. NAME
# 6. PRESENT  STREET
# 7. ADDRESS
# 8. CITY, STATE AND
# 9. ZIP
# 10. SECTION A -
# 11. PHONE
# 12. HOME
# 13. APPLICANT
# 14. CELL
# 15. PHONE
# 16. AMOUNT  OF  LOAN
# 17. REQUESTED
# 18. REQUESTED MOS. TO
# 19. PAY
# 20. HOW LONG AT THIS
# ... (truncated)
#
# Full text saved to: data\raw\loan_applications\Personal-Loan-Application-with-Disclosures-Fill-Form.txt
#
# Extraction successful!
#
# ==================================================
# Processing: URLA_2019_Borrower_v28.pdf
# ==================================================
#
# Analyzing URLA_2019_Borrower_v28.pdf:
#
# Extracted Text Preview:
# To be completed by the Lender:
# Lender Loan No./Universal Loan Identifier
#
# Agency Case No.
#
# Uniform Residential Loan Application
# Verify and complete the information on this application. If you are applying for this loan with others, each additional Borrower must provide
# information as directed by your Lender.
#
# Section 1: Borrower Information. This section asks about your personal information and your income from
# employment and other sources, such as retirement, that you want considered to qualify for this loan.
#
# 1a. Personal Information
#
# Name (First, Middle, Last, Suffix)
#
# Alternate Names – List any names by which you are known or any names
# under which credit was previously received  (First, Middle, Last, Suffix)
#
# Type of Credit
#
# I am applying for individual credit.
# I am applying for joint credit.  Total Number of Borrowers:
# Each Borrower intends to apply for joint credit. Your initials:
#
# –
# Social Security Number
# (or Individual Taxpayer Identification Number)
#
# –
#
# Date of Birth
# (mm/dd/yyyy)
# /
#
# /
#
# Citizenship
#
# U.S. Citizen
# Permanent Resident Alien
# Non-Permanent Resident Alien
#
# List Name(s) of Other Borrower(s) Applying for this Loan
# (First, Middle, Last, Suffix) – Use a separator between names
#
# Marital Status
# Married
# Separated
# Unmarried
# (Single, Divorced, Widowed, Civil Union, Domestic Partnership, Registered
# Reciprocal Beneficiary Relationship)
#
# Dependents (not listed by another Borrower)
# Number
# Ages
#
# Contact Information
#
# Home Phone (
# (
# Cell Phone
# (
# Work Phone
#
#  )
#  )
#  )
#
#  –
#  –
#  –
#
# Email
#
# Current Address
# Street
# City
#
#  State
#
#  ZIP
#
# Ext.
#
# Unit #
# Country
#
# How Long at Current Address?
#
#  Years
#
#  Months    Housing
#
# No primary housing expense
#
# Own
#
# Rent
#
# ($
#
#  /month)
#
# If at Current Address for LESS than 2 years, list Former Address
# Street
# City
#
# Does not apply
#
#  State
#
#  ZIP
#
# Unit #
# Country
#
# How Long at Former Address?
#
#  Year
#
# Document Structure Analysis:
#
# Detected Sections/Fields:
# 1. To be completed by the Lender:
# 2. Section 1: Borrower Information. This section asks about your personal information and your income from
# 3. I am applying for joint credit.  Total Number of Borrowers:
# 4. Each Borrower intends to apply for joint credit. Your initials:
# 5. ZIP
# 6. ZIP
# 7. ZIP
# 8. ZIP
# 9. Check if this statement applies:
# 10. TOTAL $
# 11. ZIP
# 12. Check if this statement applies:
# 13. TOTAL $
# 14. ZIP
# 15. Include income from other sources below. Under Income Source, choose from the sources listed here:
# 16. NOTE: Reveal alimony, child support, separate maintenance, or other income ONLY IF you want it considered in determining your qualification
# 17. Borrower Name:
# 18. Section 2: Financial Information — Assets and Liabilities. This section asks about things you own that
# 19. Include all accounts below. Under Account Type, choose from the types listed here:
# 20. Include all other assets and credits below. Under Asset or Credit Type, choose from the types listed here:
# ... (truncated)
#
# Full text saved to: data\raw\loan_applications\URLA_2019_Borrower_v28.txt
#
# Extraction successful!
#
# ==================================================
# Processing: mill-citiescommunity-investments-loan-policies.pdf
# ==================================================
#
# Analyzing mill-citiescommunity-investments-loan-policies.pdf:
#
# Extracted Text Preview:
# Lowell Community Loan Fund, Inc
#                      DBA
#  Mill Cities Community Investments
#
#               Loan Policies
#
# Approved at February 19, 2009 Board
# meeting.
#
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Table of Contents:                                                                                                                      Page#
# 1.  Objective……………………………………………………………………………………………………………4
# 2.  General Policy…………………………………………………………………………………………………….4
# A.  Eligible borrowers………………………………………………………………………………………..4
#
# B.  Conflict of Interest…………………………………………………………………………………….….4
#
# C.  Allowable purposes of financing……………………………………………………………..…...5
#
# D.  Types of loans……………………………………………………………………………………………….5
#
# E.  Investment area……………………………………………………………………………………………6
#
# F.  Lending authority…………………………………………………………………..........................6
#
# G.  Pricing of loans………………………………………………………………………………………………6
#
# H.  Application Fee……………………………………………………………………………………………..6
#
# I.  Commitment fee……………………………………………………………………………………………6
#
# J.  Rehab Fee………………………………………………………………………………………………………6
#
# K.  Additional fees……………………………………………………………………………………………....7
# 3.   Sale to NHSA ……………………………………………………………………………………………………...7
# A.  First Mortgages……………………………………………………………………………………………..7
#
# B.  Documentation……………………………………………………………………………………………..7
#
# C.  Second mortgages…………………………………………………………………………………………7
#
# 4.   Owner occupied  residential second mortgages for acquisition………………………….7
# A.  Application…………………………………………………………………………………………………….7
#
# B.  Credit investigation……………………………………………………………………………………….8
#
# C.  Amortization………………………………………………………………………………………………….9
#
# D.  Collateral……………………………………………………………………………………………………….9
#
# 5.  Owner occupied residential second mortgage for home improvement………………..9
# A.  Application……………………………………………………………………………………………………..9
#
# B.  Credit investigation……………………………………………………………………………………….10
#
# C.  Amortization………………………………………………………………………………………………….11
#
# D.  Collateral………………………………………
#
# Document Structure Analysis:
#
# Detected Sections/Fields:
# 1. DBA
# 2. Table of Contents:                                                                                                                      Page#
# 3. 1. Objective:
# 4. 2. General Policy:
# 5. conflict of interest and will not be accepted:
# 6. need a full board approval prior to commitment:
# 7. MCCI will offer the following loan products:
# 8. The two second mortgage products offered by MCCI shall observe the following criteria:
# 9. and the licensed contractor observing the following schedule:
# 10. G.   Pricing of loans:
# 11. fixed as follows:
# 12. consummation of the loan):
# 13. be able to provide the following information:
# 14. Credit history: A credit report will be obtained for most loans.  After obtaining an initial
# 15. Alternative credit history: An alternative means may be used to develop a credit history,
# 16. be able to provide the following information:
# 17. Credit history: A credit report will be obtained for most loans.
# 18. Alternative credit history: An alternative means may be used to develop a credit history,
# 19. A Seven point risk scale will be utilized:
# 20. the following:
# ... (truncated)
#
# Full text saved to: data\raw\policy_documents\mill-citiescommunity-investments-loan-policies.txt
#
# Extraction successful!
#
# ==================================================
# Processing: section3-2.pdf
# ==================================================
#
# Analyzing section3-2.pdf:
#
# Extracted Text Preview:
# LOANS
#
# Section 3.2
#
# INTRODUCTION.............................................................. 3
# LOAN ADMINISTRATION ............................................. 3
# Lending Policies ............................................................. 3
# Loan Review Systems .................................................... 4
# Credit Risk Rating or Grading Systems ..................... 4
# Loan Review System Elements .................................. 5
# Current Expected Credit Losses (CECL) ....................... 6
# Allowance for Loan and Lease Losses (ALLL) ............. 6
# Responsibility of the Board and Management ........... 7
# Factors to Consider in Estimating Credit Losses........ 7
# Examiner Responsibilities .......................................... 8
# Regulatory Reporting of the ALLL ............................ 8
# Accounting and Reporting Treatment ........................ 8
# PORTFOLIO COMPOSITION .......................................... 9
# Commercial Loans ......................................................... 9
# General ....................................................................... 9
# Accounts Receivable Financing ................................... 10
# Leveraged Lending ....................................................... 11
# Applicability ............................................................. 11
# General ..................................................................... 11
# Risk Management Framework ................................. 12
# General Policies ....................................................... 12
# Participations Purchased .......................................... 12
# Underwriting Standards............................................ 12
# Credit Analysis ......................................................... 13
# Valuation Standards ................................................. 13
# Risk Rating Leveraged Loans .................................. 14
# Problem Credit Management...................................
#
# Document Structure Analysis:
#
# Detected Sections/Fields:
# 1. LOANS
# 2. INTRODUCTION.............................................................. 3
# 3. LOAN ADMINISTRATION ............................................. 3
# 4. PORTFOLIO COMPOSITION .......................................... 9
# 5. OTHER CREDIT ISSUES .............................................. 34
# 6. LOAN PROBLEMS ........................................................ 46
# 7. SELECTING A LOAN REVIEW SAMPLE IN A RISK-
# 8. FOCUSED EXAMINATION .......................................... 49
# 9. LOAN EVALUATION AND CLASSIFICATION ........ 52
# 10. LOANS
# 11. CREDIT SCORING ........................................................ 76
# 12. SUBPRIME LENDING .................................................. 77
# 13. GOVERNMENT GUARANTEED LENDING AND
# 14. GOVERNMENT INSURED MORTGAGE LENDING . 87
# 15. CONCENTRATIONS ...................................................... 63
# 16. FEDERAL FUNDS SOLD AND REPURCHASE
# 17. AGREEMENTS ............................................................... 64
# 18. FUNDAMENTAL LEGAL CONCEPTS AND
# 19. DEFINITIONS ................................................................. 65
# 20. CONSIDERATION OF BANKRUPTCY LAW AS IT
# ... (truncated)
#
# Full text saved to: data\raw\policy_documents\section3-2.txt
#
# Extraction successful!
